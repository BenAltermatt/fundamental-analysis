# %% [markdown]
# # Data Preparation
#
# I need to prepare data for my models to work so I plan on doing that here within this notebook.

# %%
# Pandas is a huge tool for this stuff
import pandas as pd

# %% [markdown]
# ## Visualization
#
# My first step here is to get an idea of the shape of the data I am working with.

# %%
# this ran for like 4 minutes without doing anything
# frame = pd.read_csv('us-stock-fundamentals.csv', header=None, error_bad_lines=False)

# there's a possibility the files are too large to do anything worthwhile with. I'll try taking a chunk.
frame = pd.read_csv('us-stock-fundamentals.csv', on_bad_lines='skip', sep=';')

frame
# Out:
#                                                  Indicator  Quarter  \
# 0                          Comprehensive Income Net Of Tax  2012/Q4
# 1                          Comprehensive Income Net Of Tax  2012/Q3
# 2                          Comprehensive Income Net Of Tax  2012/Q1
# 3                          Comprehensive Income Net Of Tax  2013/Q3
# 4                          Comprehensive Income Net Of Tax  2011/Q2
# ...                                                    ...      ...
# 3549953  Weighted Average Number Of Diluted Shares Outs...  2011/Q1
# 3549954  Weighted Average Number Of Diluted Shares Outs...  2014/Q1
# 3549955  Weighted Average Number Of Diluted Shares Outs...  2015/Q1
# 3549956  Weighted Average Number Of Diluted Shares Outs...  2015/Q2
# 3549957  Weighted Average Number Of Diluted Shares Outs...  2015/Q4
#
#                          Latest NAICS Industry Sector Name  \
# 0        Administrative and Support and Waste Managemen...
# 1        Administrative and Support and Waste Managemen...
# 2        Administrative and Support and Waste Managemen...
# 3        Administrative and Support and Waste Managemen...
# 4        Administrative and Support and Waste Managemen...
# ...                                                    ...
# 3549953                                      Manufacturing
# 3549954                                      Manufacturing
# 3549955                                      Manufacturing
# 3549956                                      Manufacturing
# 3549957                                      Manufacturing
#
#                            Latest Name   SEC ID      Value
# 0                         Nxt-Id, Inc.  1566826        NaN
# 1                         Nxt-Id, Inc.  1566826        NaN
# 2                         Nxt-Id, Inc.  1566826        NaN
# 3                         Nxt-Id, Inc.  1566826        NaN
# 4                         Nxt-Id, Inc.  1566826        NaN
# ...                                ...      ...        ...
# 3549953               Terra Tech Corp.  1451512        NaN
# 3549954  Technical Communications Corp    96699  1838907.0
# 3549955  Technical Communications Corp    96699  1846399.0
# 3549956  Technical Communications Corp    96699  1839520.0
# 3549957  Technical Communications Corp    96699        NaN
#
# [3549958 rows x 6 columns]

# %% [markdown]
# ## US-Stock-Fundamentals
#
# Actually seems to have very little useful data for us to work with, but it is interesting that between this and the othe CSV we were provided, ids seem to be common. The **SEC ID** for a stock seems to be a regular representative of a company which will be nice when we need to corroborate or consolidate data between companies. It also seems to be the case that the time frame over which we are going to have access to these fundamental indicators is once a quarter, which is about 4 times a year, pretty self explanatorily.

# %%
frame = pd.read_csv('indicators_by_company.csv')

frame
# Out:
#          company_id                                       indicator_id  2010  \
# 0           1000045  AccountsPayableAndAccruedLiabilitiesCurrentAnd...   NaN
# 1           1000045  AccumulatedDepreciationDepletionAndAmortizatio...   NaN
# 2           1000045                          AdjustmentForAmortization   NaN
# 3           1000045                                             Assets   NaN
# 4           1000045                   AssetsHeldForSaleAtCarryingValue   NaN
# ...             ...                                                ...   ...
# 1907878        9984  UnrecognizedTaxBenefitsInterestOnIncomeTaxesAc...   NaN
# 1907879        9984  UnrecognizedTaxBenefitsReductionsResultingFrom...   NaN
# 1907880        9984   ValuationAllowanceDeferredTaxAssetChangeInAmount   NaN
# 1907881        9984    WeightedAverageNumberOfDilutedSharesOutstanding   NaN
# 1907882        9984      WeightedAverageNumberOfSharesOutstandingBasic   NaN
#
#                 2011         2012         2013         2014         2015  2016
# 0          6612429.0    7405579.0    8924919.0    7841070.0    5839000.0   NaN
# 1                NaN    2111343.0    2242703.0    2236449.0    2462000.0   NaN
# 2                NaN  -11482251.0  -13490892.0  -13852305.0  -13811000.0   NaN
# 3        257236034.0  263835468.0  283429579.0  302528591.0  325309000.0   NaN
# 4          1373001.0    1203664.0    1696330.0          NaN          NaN   NaN
# ...              ...          ...          ...          ...          ...   ...
# 1907878          0.0          0.0    1031000.0    1031000.0    1923000.0   NaN
# 1907879     177000.0          0.0          0.0          NaN     215000.0   NaN
# 1907880  -13355000.0    8255000.0   -6063000.0          NaN          NaN   NaN
# 1907881   55931882.0   55224457.0   54973344.0   55723267.0   55513219.0   NaN
# 1907882   55214586.0   54626453.0   53860308.0   54791030.0   55028063.0   NaN
#
# [1907883 rows x 9 columns]

# %% [markdown]
# ## Indicators-By-Company
#
# This is a nicer data set that seems to come with a more useful amount of information. The shape is interesting, however. To make it work nicer with something like pandas, it's nice that it has 9 columns, but that leaves us with multiple rows for single companies. These different rows represent different indicators. It's also worth mentioning that this data is yearly now and seems to span 5 years at best fo r alot of these companies.
#
# It might be worthwhile to look in to how many of these indicators exist for different companies.

# %%
# luckily, single companies seem to be grouped by their ids which makes this a little easier to do
indicator_counts = dict()

# I want to see what the indicator numbers look like for each one of these companies throughout the entire thing.
unique_inds = frame['indicator_id'].unique()

for ind in range(len(unique_inds)):
    print('{:.2f}%'.format(ind / len(unique_inds) * 100), end='\r')
    indicator_counts[unique_inds[ind]] = len(frame[frame['indicator_id'] == unique_inds[ind]])
# Out:
# 99.99%

# %%
# it may be useful to have a sorted array of the indicators by the amount of data points we have for them

count = [(-count, val) for val, count in indicator_counts.items()]
count.sort()

indicators_by_name = list(indicator_counts.keys())
indicators_by_name.sort()

indicators = open("Indicator-Names.txt", "w")

for ind in indicators_by_name:
    indicators.write(ind + '\n')

indicators.close()

# %% [markdown]
# ## Indicators
#
# I need to find the data indicators that are of particular interest to me. These are values that can be used to calculate heuristics for fundamental analysis to plug into the system _and_ have high enough counts to present a large enough training set for the data I am using.
#
# Soon I may have to decide what to do about incomplete records and how I will treat them within the data set I am building, but for now I need to make sure that will be enough of an issue later on.
#
# ---
# ### Indicator-Names.txt
# This is an alphabetical list of all of the indicators present within the data set I am currently looking at.

# %% [markdown]
# ## Important Indicators
#
# Here I will keep a list of indicators of interest to me and their associated calculations they may be pertinent to.
#
# |Indicator|Indicator Count|
# |--|--|
# |EarningsPerShareBasic|5501|
# |EarningsPerShareDiluted|5084|
# |Price|??|
#
# It has come to my attention that I need access to prices to do many of these calculations. I will look through the data set for the current values I might be able to use to calculate price, or see if it has any prices. If there aren't, I will need to bring in other files.

# %%
print(indicator_counts['EarningsPerShareBasic'])
print(indicator_counts['EarningsPerShareDiluted'])
print(indicator_counts['SharesIssuedPricePerShare'])
print(indicator_counts['FairValueInputsLongTermRevenueGrowthRate'])
print(indicator_counts['CommonStockSharesOutstanding'])


print(count[:40])
# Out:
# 5501
# 5084
# 182
# 44
# 7571
# [(-9469, 'LiabilitiesAndStockholdersEquity'), (-9460, 'Assets'), (-8926, 'NetIncomeLoss'), (-8843, 'StockholdersEquity'), (-8735, 'CashAndCashEquivalentsAtCarryingValue'), (-8412, 'CashAndCashEquivalentsPeriodIncreaseDecrease'), (-8374, 'RetainedEarningsAccumulatedDeficit'), (-8303, 'CommonStockSharesAuthorized'), (-8192, 'NetCashProvidedByUsedInOperatingActivities'), (-8093, 'CommonStockValue'), (-8092, 'CommonStockSharesIssued'), (-8078, 'NetCashProvidedByUsedInFinancingActivities'), (-7848, 'CommonStockParOrStatedValuePerShare'), (-7571, 'CommonStockSharesOutstanding'), (-7512, 'Liabilities'), (-7435, 'LiabilitiesCurrent'), (-7432, 'AssetsCurrent'), (-7430, 'PropertyPlantAndEquipmentNet'), (-7412, 'NetCashProvidedByUsedInInvestingActivities'), (-7205, 'OperatingIncomeLoss'), (-7031, 'IncomeTaxExpenseBenefit'), (-6738, 'InterestExpense'), (-6551, 'AccumulatedDepreciationDepletionAndAmortizationPropertyPlantAndEquipment'), (-6484, 'ShareBasedCompensation'), (-6034, 'DeferredTaxAssetsValuationAllowance'), (-6003, 'PreferredStockSharesAuthorized'), (-6001, 'WeightedAverageNumberOfSharesOutstandingBasic'), (-5991, 'PropertyPlantAndEquipmentGross'), (-5981, 'PaymentsToAcquirePropertyPlantAndEquipment'), (-5970, 'InterestPaid'), (-5668, 'AccountsPayableCurrent'), (-5576, 'ComprehensiveIncomeNetOfTax'), (-5562, 'AccumulatedOtherComprehensiveIncomeLossNetOfTax'), (-5562, 'EffectiveIncomeTaxRateReconciliationAtFederalStatutoryIncomeTaxRate'), (-5501, 'EarningsPerShareBasic'), (-5498, 'OperatingLeasesFutureMinimumPaymentsDueCurrent'), (-5459, 'WeightedAverageNumberOfDilutedSharesOutstanding'), (-5440, 'OperatingLeasesFutureMinimumPaymentsDueInTwoYears'), (-5315, 'DeferredIncomeTaxExpenseBenefit'), (-5307, 'OperatingLeasesFutureMinimumPaymentsDueInThreeYears')]

# %%
frame[(frame['indicator_id'] == 'StockholdersEquity')]
# Out:
#          company_id        indicator_id          2010          2011  \
# 116         1000045  StockholdersEquity           NaN           NaN
# 499         1000180  StockholdersEquity  5.782624e+09  7.064358e+09
# 796         1000228  StockholdersEquity           NaN  2.432222e+09
# 1133        1000229  StockholdersEquity           NaN  1.779030e+08
# 1357        1000230  StockholdersEquity           NaN  2.820917e+07
# ...             ...                 ...           ...           ...
# 1906624       99302  StockholdersEquity           NaN  2.737800e+07
# 1906835       99359  StockholdersEquity           NaN  3.815200e+07
# 1907168       99771  StockholdersEquity           NaN  1.179690e+08
# 1907596       99780  StockholdersEquity           NaN  1.863800e+09
# 1907867        9984  StockholdersEquity           NaN  7.224000e+08
#
#                  2012          2013          2014          2015  2016
# 116      1.269651e+08  1.419376e+08  8.988794e+07  1.028490e+08   NaN
# 499      7.263901e+09  6.967872e+09  6.528059e+09  5.738924e+09   NaN
# 796      2.613585e+09  2.785197e+09  2.813594e+09  2.884256e+09   NaN
# 1133     1.822300e+08  1.633230e+08  8.757300e+07 -2.906400e+07   NaN
# 1357     3.064436e+07  3.019867e+07  3.100657e+07  2.663061e+07   NaN
# ...               ...           ...           ...           ...   ...
# 1906624  3.165000e+07  3.008300e+07  3.431800e+07  3.891100e+07   NaN
# 1906835  4.307200e+07  5.048400e+07  6.711500e+07           NaN   NaN
# 1907168           NaN  8.871000e+07  8.100300e+07           NaN   NaN
# 1907596  2.053000e+09  2.402100e+09  2.995900e+09  3.653900e+09   NaN
# 1907867  8.001180e+08  1.141414e+09  1.111793e+09  1.127753e+09   NaN
#
# [8843 rows x 9 columns]

# %%
frame[(frame['indicator_id'] == 'WeightedAverageNumberOfSharesOutstandingBasic')]
# Out:
#          company_id                                   indicator_id  \
# 123         1000045  WeightedAverageNumberOfSharesOutstandingBasic
# 521         1000180  WeightedAverageNumberOfSharesOutstandingBasic
# 829         1000228  WeightedAverageNumberOfSharesOutstandingBasic
# 1152        1000229  WeightedAverageNumberOfSharesOutstandingBasic
# 1370        1000230  WeightedAverageNumberOfSharesOutstandingBasic
# ...             ...                                            ...
# 1906635       99302  WeightedAverageNumberOfSharesOutstandingBasic
# 1906845       99359  WeightedAverageNumberOfSharesOutstandingBasic
# 1907200       99771  WeightedAverageNumberOfSharesOutstandingBasic
# 1907617       99780  WeightedAverageNumberOfSharesOutstandingBasic
# 1907882        9984  WeightedAverageNumberOfSharesOutstandingBasic
#
#                 2010         2011         2012         2013         2014  \
# 123              NaN          NaN   11977174.0   12096000.0   12012765.0
# 521      232531000.0  239484000.0  242076000.0  234886000.0  222714000.0
# 829              NaN   90120000.0   87499000.0   85926000.0   84265000.0
# 1152             NaN   46286000.0   47211000.0   45692000.0   44362000.0
# 1370             NaN          NaN    6455817.0          NaN          NaN
# ...              ...          ...          ...          ...          ...
# 1906635          NaN    7309000.0    7404000.0    7080000.0    6798000.0
# 1906845          NaN    9473000.0    9511000.0    9643000.0    9778000.0
# 1907200          NaN          NaN          NaN    6449726.0    6452557.0
# 1907617          NaN   77500000.0   77300000.0   76400000.0  151000000.0
# 1907882          NaN   55214586.0   54626453.0   53860308.0   54791030.0
#
#                 2015  2016
# 123        7622000.0   NaN
# 521      205443000.0   NaN
# 829       82844000.0   NaN
# 1152      42747000.0   NaN
# 1370             NaN   NaN
# ...              ...   ...
# 1906635    6887000.0   NaN
# 1906845          NaN   NaN
# 1907200          NaN   NaN
# 1907617  150200000.0   NaN
# 1907882   55028063.0   NaN
#
# [6001 rows x 9 columns]

# %% [markdown]
# ## New Data Set Needed - Prices
#
# My worst fears have been realized. I don't seem to have any consistent, reliable access to historical price data for these companies. I will have to use another data set. The problem here is, many free data sets that include prices for many stocks are full of daily stock information, and I need about five days worth of information, which means I may have to use a data set to build my own.

# %% [markdown]
# ## TOD - Fundamental Analysis API?
#
# There's a chance I have been going about this all wrong. I have been looking for free online data sets to use, but the other good option for data collection is API usage. Many of the data sets I have found that weren't behind a paywall offered difficulties when it came to the processing of data, and so the left over ones were sparse and not too much to my liking. I'm going to take a look into apis.

# %%
# I actually didn't have the original modules needed to do this installed and I 
# am not good at managing the different python environments on my pc so this will have
# to do for now
import sys
# !{sys.executable} -m pip install fundamentalanalysis
# !{sys.executable} -m pip install requests

import fundamentalanalysis as fa

# let's play around a little bit with the fundamental analysis api
# on my repo this file won't exist
apikey = open('apikey.txt', 'r')
key = apikey.readline()
apikey.close()
# Out:
# Requirement already satisfied: fundamentalanalysis in c:\python38\lib\site-packages (0.2.14)
# WARNING: You are using pip version 20.3.3; however, version 22.3 is available.
# You should consider upgrading via the 'c:\Python38\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: requests in c:\python38\lib\site-packages (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\python38\lib\site-packages (from requests) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\python38\lib\site-packages (from requests) (1.26.12)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\python38\lib\site-packages (from requests) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\python38\lib\site-packages (from requests) (3.4)
# WARNING: You are using pip version 20.3.3; however, version 22.3 is available.
# You should consider upgrading via the 'c:\Python38\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ## API Information
#
# I have a free plan, currently. I may buy one month's worth of data if I really find it worthwhile, but as of now I am rate limited to something like 300 requests per day. (This is like... obscenely low unless I can get a huge batch of info from a single request. We'll see how this turns out.)
#
# [Link To API documentation](https://pypi.org/project/fundamentalanalysis/)
#
# I ended up dropping about $20 on the lowest tier for a month of data collection. It's frustrating, but the data set is thorough and It will give me good information to work with. I was limited to using the same end point a maximum of 5 times without it.

# %%
# Now I have to build my data set, so I need an example of what metrics they have in their key metrics endpoint
intc_vals = fa.key_metrics('INTC', key, 'quarterly')
intc_vals
# Out:
#                                                        2021  \
# period                                                   FY
# revenuePerShare                                   19.468835
# netIncomePerShare                                  4.894802
# operatingCashFlowPerShare                          7.388766
# freeCashFlowPerShare                               2.380389
# cashPerShare                                            7.0
# bookValuePerShare                                 23.501109
# tangibleBookValuePerShare                         15.067258
# shareholdersEquityPerShare                        23.501109
# interestDebtPerShare                               9.533875
# marketCap                               210824454317.400024
# enterpriseValue                         244098454317.400024
# peRatio                                           10.611257
# priceToSalesRatio                                  2.667853
# pocfratio                                          7.029591
# pfcfRatio                                          21.81996
# pbRatio                                            2.210108
# ptbRatio                                           2.210108
# evToSales                                          3.088915
# enterpriseValueOverEBITDA                          7.159992
# evToOperatingCashFlow                              8.139057
# evToFreeCashFlow                                  25.263761
# earningsYield                                       0.09424
# freeCashFlowYield                                   0.04583
# debtToEquity                                       0.351291
# debtToAssets                                       0.433565
# netDebtToEBITDA                                    0.976006
# currentRatio                                       2.101741
# interestCoverage                                  32.589615
# incomeQuality                                      1.509513
# dividendYield                                      0.026771
# payoutRatio                                        0.284075
# salesGeneralAndAdministrativeToRevenue             0.082798
# researchAndDdevelopementToRevenue                   0.19222
# intangiblesToTotalAssets                           0.203277
# capexToOperatingCashFlow                          -0.677837
# capexToRevenue                                    -0.257251
# capexToDepreciation                               -1.723965
# stockBasedCompensationToRevenue                    0.025764
# grahamNumber                                      50.874832
# roic                                               0.138041
# returnOnTangibleAssets                             0.148077
# grahamNetNet                                      -7.913587
# workingCapital                                  30256000000
# tangibleAssetValue                              61158000000
# netCurrentAssetValue                           -15297000000
# investedCapital                                    0.399419
# averageReceivables                               8119500000
# averagePayables                                  5664000000
# averageInventory                                 9601500000
# daysSalesOutstanding                              43.680464
# daysPayablesOutstanding                           59.577239
# daysOfInventoryOnHand                             111.71121
# receivablesTurnover                                8.356138
# payablesTurnover                                   6.126501
# inventoryTurnover                                  3.267353
# roe                                                 0.20828
# capexPerShare                                     -5.008376
#
#                                                        2020  \
# period                                                   FY
# revenuePerShare                                   18.544177
# netIncomePerShare                                  4.977137
# operatingCashFlowPerShare                          8.426768
# freeCashFlowPerShare                               4.984758
# cashPerShare                                       5.690641
# bookValuePerShare                                 19.299357
# tangibleBookValuePerShare                         10.726602
# shareholdersEquityPerShare                        19.299357
# interestDebtPerShare                               8.818766
# marketCap                               232792554121.400024
# enterpriseValue                         263328554121.400024
# peRatio                                           11.138933
# priceToSalesRatio                                  2.989618
# pocfratio                                          6.579034
# pfcfRatio                                         11.121903
# pbRatio                                            2.872634
# ptbRatio                                           2.872634
# evToSales                                          3.381773
# enterpriseValueOverEBITDA                           6.93956
# evToOperatingCashFlow                              7.442023
# evToFreeCashFlow                                  12.580792
# earningsYield                                      0.089775
# freeCashFlowYield                                  0.089913
# debtToEquity                                       0.418285
# debtToAssets                                       0.470655
# netDebtToEBITDA                                    0.804723
# currentRatio                                       1.908742
# interestCoverage                                  37.643879
# incomeQuality                                      1.693095
# dividendYield                                      0.023918
# payoutRatio                                        0.266424
# salesGeneralAndAdministrativeToRevenue                  0.0
# researchAndDdevelopementToRevenue                  0.174092
# intangiblesToTotalAssets                           0.235135
# capexToOperatingCashFlow                          -0.408461
# capexToRevenue                                    -0.185611
# capexToDepreciation                               -1.180897
# stockBasedCompensationToRevenue                     0.02381
# grahamNumber                                      46.489245
# roic                                               0.184499
# returnOnTangibleAssets                             0.178481
# grahamNetNet                                      -9.254108
# workingCapital                                  22495000000
# tangibleAssetValue                              45041000000
# netCurrentAssetValue                           -24804000000
# investedCapital                                    0.449184
# averageReceivables                               6782000000
# averagePayables                                  5581000000
# averageInventory                                 8427000000
# daysSalesOutstanding                              31.790489
# daysPayablesOutstanding                           59.467669
# daysOfInventoryOnHand                             89.792877
# receivablesTurnover                               11.481421
# payablesTurnover                                   6.137789
# inventoryTurnover                                   4.06491
# roe                                                0.257891
# capexPerShare                                      -3.44201
#
#                                                        2019  \
# period                                                   FY
# revenuePerShare                                   16.292733
# netIncomePerShare                                  4.765225
# operatingCashFlowPerShare                          7.503962
# freeCashFlowPerShare                               3.833371
# cashPerShare                                       2.971021
# bookValuePerShare                                 17.546751
# tangibleBookValuePerShare                          9.181798
# shareholdersEquityPerShare                        17.546751
# interestDebtPerShare                               6.676477
# marketCap                               290152740600.799988
# enterpriseValue                         314959740600.799988
# peRatio                                           13.785288
# priceToSalesRatio                                  4.031859
# pocfratio                                          8.754043
# pfcfRatio                                         17.136354
# pbRatio                                            3.743713
# ptbRatio                                           3.743713
# evToSales                                          4.376568
# enterpriseValueOverEBITDA                          8.903959
# evToOperatingCashFlow                              9.502481
# evToFreeCashFlow                                  18.601449
# earningsYield                                      0.072541
# freeCashFlowYield                                  0.058355
# debtToEquity                                       0.326538
# debtToAssets                                        0.43117
# netDebtToEBITDA                                    0.701298
# currentRatio                                       1.400224
# interestCoverage                                   45.06135
# incomeQuality                                      1.574734
# dividendYield                                      0.019217
# payoutRatio                                        0.264918
# salesGeneralAndAdministrativeToRevenue             0.085458
# researchAndDdevelopementToRevenue                  0.185674
# intangiblesToTotalAssets                           0.271769
# capexToOperatingCashFlow                          -0.489154
# capexToRevenue                                     -0.22529
# capexToDepreciation                               -1.497598
# stockBasedCompensationToRevenue                    0.023692
# grahamNumber                                      43.374186
# roic                                               0.192927
# returnOnTangibleAssets                             0.211706
# grahamNetNet                                      -8.065599
# workingCapital                                   8929000000
# tangibleAssetValue                              40556000000
# netCurrentAssetValue                           -27626000000
# investedCapital                                    0.374187
# averageReceivables                               7220500000
# averagePayables                                  4854500000
# averageInventory                                 8585500000
# daysSalesOutstanding                              38.845758
# daysPayablesOutstanding                           50.518692
# daysOfInventoryOnHand                            107.009556
# receivablesTurnover                                9.396135
# payablesTurnover                                   7.225048
# inventoryTurnover                                   3.41091
# roe                                                0.271573
# capexPerShare                                     -3.670591
#
#                                                        2018            2017  \
# period                                                   FY              FY
# revenuePerShare                                   15.364997       13.350564
# netIncomePerShare                                  4.565821        2.042331
# operatingCashFlowPerShare                          6.382997        4.703255
# freeCashFlowPerShare                               3.090653         2.19783
# cashPerShare                                       2.526567        2.978515
# bookValuePerShare                                 16.170679        14.68177
# tangibleBookValuePerShare                          8.378443        6.966816
# shareholdersEquityPerShare                        16.170679        14.68177
# interestDebtPerShare                               5.818044        5.841098
# marketCap                               215379805850.099976  234955977649.5
# enterpriseValue                         238719805850.099976  258335977649.5
# peRatio                                           10.230362       24.472032
# priceToSalesRatio                                  3.040027        3.743662
# pocfratio                                          7.317879       10.626684
# pfcfRatio                                         15.113312        22.74061
# pbRatio                                            2.888561        3.404222
# ptbRatio                                           2.888561        3.404222
# evToSales                                          3.369464        4.116186
# enterpriseValueOverEBITDA                          7.262544        8.869296
# evToOperatingCashFlow                              8.110893       11.684124
# evToFreeCashFlow                                  16.751092       25.003482
# earningsYield                                      0.097748        0.040863
# freeCashFlowYield                                  0.066167        0.043974
# debtToEquity                                       0.336601        0.362755
# debtToAssets                                       0.414034        0.432977
# netDebtToEBITDA                                     0.71007        0.802692
# currentRatio                                       1.731445        1.693359
# interestCoverage                                  49.820513       27.764706
# incomeQuality                                      1.397996        2.302885
# dividendYield                                      0.025727        0.021587
# payoutRatio                                        0.263193        0.528278
# salesGeneralAndAdministrativeToRevenue             0.095274        0.118736
# researchAndDdevelopementToRevenue                  0.191156        0.207693
# intangiblesToTotalAssets                           0.284059        0.301293
# capexToOperatingCashFlow                          -0.515799         -0.5327
# capexToRevenue                                    -0.214276       -0.187664
# capexToDepreciation                               -1.670996       -1.448887
# stockBasedCompensationToRevenue                    0.021821        0.021638
# grahamNumber                                      40.758183       25.974283
# roic                                               0.209418        0.169483
# returnOnTangibleAssets                             0.229801         0.11149
# grahamNetNet                                      -7.083713       -6.735854
# workingCapital                                  12161000000     12079000000
# tangibleAssetValue                              38633000000     32751000000
# netCurrentAssetValue                           -24194000000    -23864000000
# investedCapital                                    0.353513        0.388487
# averageReceivables                               6752000000      6194500000
# averagePayables                                  4702500000      4254500000
# averageInventory                                 7840000000      7705000000
# daysSalesOutstanding                                34.6309       32.608706
# daysPayablesOutstanding                           51.483162        45.16418
# daysOfInventoryOnHand                             97.648372      107.712251
# receivablesTurnover                                10.53972        11.19333
# payablesTurnover                                   7.089697        8.081626
# inventoryTurnover                                  3.737902        3.388658
# roe                                                0.282352        0.139107
# capexPerShare                                     -3.292344       -2.505424
#
#                                                 2016                 2015  \
# period                                            FY                   FY
# revenuePerShare                            12.555391            11.673345
# netIncomePerShare                           2.180973             2.408267
# operatingCashFlowPerShare                   4.610571             4.010333
# freeCashFlowPerShare                        2.575687              2.44011
# cashPerShare                                3.615011             5.338043
# bookValuePerShare                          14.001268            12.881695
# tangibleBookValuePerShare                   9.199789              9.85175
# shareholdersEquityPerShare                 14.001268            12.881695
# interestDebtPerShare                        5.500211              4.85175
# marketCap                               176996591486  140363201896.799988
# enterpriseValue                         196719591486  147725201896.799988
# peRatio                                    17.157483            12.290998
# priceToSalesRatio                           2.980393             2.535691
# pocfratio                                   8.116131             7.380933
# pfcfRatio                                  14.528161            12.130603
# pbRatio                                     2.672615             2.297834
# ptbRatio                                    2.672615             2.297834
# evToSales                                   3.312503             2.668688
# enterpriseValueOverEBITDA                    9.16723              6.35104
# evToOperatingCashFlow                       9.020524              7.76806
# evToFreeCashFlow                           16.147057            12.766848
# earningsYield                               0.058284              0.08136
# freeCashFlowYield                           0.068832             0.082436
# debtToEquity                                0.311796             0.328002
# debtToAssets                                0.407837             0.389093
# netDebtToEBITDA                             0.919102             0.316509
# currentRatio                                 1.74899             2.449188
# interestCoverage                           17.563438            41.548961
# incomeQuality                               2.113998             1.665236
# dividendYield                               0.027825             0.032459
# payoutRatio                                 0.477414             0.398949
# salesGeneralAndAdministrativeToRevenue      0.141395             0.143257
# researchAndDdevelopementToRevenue           0.214525             0.219095
# intangiblesToTotalAssets                    0.208185             0.150455
# capexToOperatingCashFlow                   -0.441352            -0.391544
# capexToRevenue                             -0.162073            -0.134514
# capexToDepreciation                        -1.235558            -0.854781
# stockBasedCompensationToRevenue             0.024315             0.023575
# grahamNumber                               26.211993            26.419832
# roic                                        0.138393             0.163169
# returnOnTangibleAssets                      0.114962             0.132492
# grahamNetNet                               -4.825793            -1.684996
# workingCapital                           15206000000          22674000000
# tangibleAssetValue                       43515000000          46717000000
# netCurrentAssetValue                    -10711000000          -1157000000
# investedCapital                             0.381768             0.371122
# averageReceivables                        5736000000           5784500000
# averagePayables                           4028000000           3822000000
# averageInventory                          6990000000           6797000000
# daysSalesOutstanding                       28.825332            31.564538
# daysPayablesOutstanding                    38.945292            36.418795
# daysOfInventoryOnHand                      87.379074            91.214693
# receivablesTurnover                        12.662473             11.56361
# payablesTurnover                            9.372121            10.022298
# inventoryTurnover                           4.177202             4.001548
# roe                                          0.15577             0.186953
# capexPerShare                              -2.034884            -1.570224
#
#                                                        2014          2013  \
# period                                                   FY            FY
# revenuePerShare                                   11.399714     10.605231
# netIncomePerShare                                  2.388084      1.935614
# operatingCashFlowPerShare                          4.166089      4.180282
# freeCashFlowPerShare                               2.085493      2.017907
# cashPerShare                                       2.867578       4.04165
# bookValuePerShare                                 11.398694     11.721529
# tangibleBookValuePerShare                          8.275454       8.57002
# shareholdersEquityPerShare                        11.398694     11.721529
# interestDebtPerShare                               2.826974      2.754527
# marketCap                               175504816861.399994  122858396521
# enterpriseValue                         186606816861.399994  130630396521
# peRatio                                           14.995285     12.771143
# priceToSalesRatio                                  3.141307      2.330925
# pocfratio                                          8.595593      5.913477
# pfcfRatio                                         17.171003     12.250314
# pbRatio                                            3.141588       2.10894
# ptbRatio                                           3.141588       2.10894
# evToSales                                          3.340018      2.478379
# enterpriseValueOverEBITDA                           7.60357      6.254148
# evToOperatingCashFlow                              9.139329      6.287562
# evToFreeCashFlow                                  18.257198     13.025266
# earningsYield                                      0.066688      0.078302
# freeCashFlowYield                                  0.058238      0.081631
# debtToEquity                                        0.21586      0.225985
# debtToAssets                                       0.392111      0.369237
# netDebtToEBITDA                                    0.452367      0.372097
# currentRatio                                       1.731934      2.364682
# interestCoverage                                  79.932292     50.372951
# incomeQuality                                      1.744532      2.159667
# dividendYield                                      0.025122      0.036457
# payoutRatio                                        0.376709      0.465593
# salesGeneralAndAdministrativeToRevenue             0.145624      0.153449
# researchAndDdevelopementToRevenue                  0.206497      0.201317
# intangiblesToTotalAssets                           0.166561       0.16959
# capexToOperatingCashFlow                          -0.499412      -0.51728
# capexToRevenue                                    -0.182513     -0.203897
# capexToDepreciation                               -1.192771     -1.338023
# stockBasedCompensationToRevenue                    0.020548      0.021211
# grahamNumber                                        24.7482      22.59398
# roic                                                0.20223      0.155997
# returnOnTangibleAssets                             0.152808      0.125432
# grahamNetNet                                      -3.371608     -1.859658
# workingCapital                                  11719000000   18516000000
# tangibleAssetValue                              40558000000   42593000000
# netCurrentAssetValue                            -8305000000   -2018000000
# investedCapital                                    0.244572      0.230809
# averageReceivables                               5604500000    5182000000
# averagePayables                                  4164500000    4275000000
# averageInventory                                 6350000000    6299500000
# daysSalesOutstanding                              28.921693     24.805153
# daysPayablesOutstanding                            49.50496     51.148582
# daysOfInventoryOnHand                             76.977691     71.873319
# receivablesTurnover                               12.620285     14.714685
# payablesTurnover                                   7.372999      7.136073
# inventoryTurnover                                  4.741634       5.07838
# roe                                                0.209505      0.165133
# capexPerShare                                     -2.080596     -2.162374
#
#                                                        2012  ...  \
# period                                                   FY  ...
# revenuePerShare                                   10.676741  ...
# netIncomePerShare                                  2.202762  ...
# operatingCashFlowPerShare                          3.779824  ...
# freeCashFlowPerShare                               1.409528  ...
# cashPerShare                                       3.635308  ...
# bookValuePerShare                                 10.248799  ...
# tangibleBookValuePerShare                          7.057246  ...
# shareholdersEquityPerShare                        10.248799  ...
# interestDebtPerShare                               2.709768  ...
# marketCap                               105165796003.199997  ...
# enterpriseValue                         110135796003.199997  ...
# peRatio                                            9.556183  ...
# priceToSalesRatio                                  1.971575  ...
# pocfratio                                          5.569042  ...
# pfcfRatio                                         14.934081  ...
# pbRatio                                            2.053899  ...
# ptbRatio                                           2.053899  ...
# evToSales                                          2.064749  ...
# enterpriseValueOverEBITDA                           4.89819  ...
# evToOperatingCashFlow                              5.832228  ...
# evToFreeCashFlow                                  15.639846  ...
# earningsYield                                      0.104644  ...
# freeCashFlowYield                                  0.066961  ...
# debtToEquity                                       0.256547  ...
# debtToAssets                                       0.392977  ...
# netDebtToEBITDA                                    0.221036  ...
# currentRatio                                        2.43123  ...
# interestCoverage                                 162.644444  ...
# incomeQuality                                      1.715947  ...
# dividendYield                                      0.041363  ...
# payoutRatio                                        0.395275  ...
# salesGeneralAndAdministrativeToRevenue             0.151047  ...
# researchAndDdevelopementToRevenue                  0.190248  ...
# intangiblesToTotalAssets                           0.189032  ...
# capexToOperatingCashFlow                          -0.627092  ...
# capexToRevenue                                    -0.222006  ...
# capexToDepreciation                               -1.574315  ...
# stockBasedCompensationToRevenue                     0.02066  ...
# grahamNumber                                      22.537802  ...
# roic                                               0.204862  ...
# returnOnTangibleAssets                             0.160878  ...
# grahamNetNet                                       -1.95041  ...
# workingCapital                                  18460000000  ...
# tangibleAssetValue                              35258000000  ...
# netCurrentAssetValue                            -1790000000  ...
# investedCapital                                    0.262641  ...
# averageReceivables                               5307500000  ...
# averagePayables                                  4302000000  ...
# averageInventory                                 6580500000  ...
# daysSalesOutstanding                              26.228323  ...
# daysPayablesOutstanding                            54.65057  ...
# daysOfInventoryOnHand                             85.582467  ...
# receivablesTurnover                               13.916254  ...
# payablesTurnover                                   6.678796  ...
# inventoryTurnover                                  4.264892  ...
# roe                                                0.214929  ...
# capexPerShare                                     -2.370296  ...
#
#                                                        2003  \
# period                                                   FY
# revenuePerShare                                    4.617895
# netIncomePerShare                                  0.864256
# operatingCashFlowPerShare                           1.76421
# freeCashFlowPerShare                               1.204075
# cashPerShare                                       2.476482
# bookValuePerShare                                  5.798376
# tangibleBookValuePerShare                          5.230734
# shareholdersEquityPerShare                         5.798376
# interestDebtPerShare                               0.177723
# marketCap                               211670611958.100006
# enterpriseValue                         204859611958.100006
# peRatio                                           37.523597
# priceToSalesRatio                                   7.02268
# pocfratio                                         18.382163
# pfcfRatio                                          26.93353
# pbRatio                                            5.592945
# ptbRatio                                           5.592945
# evToSales                                          6.796709
# enterpriseValueOverEBITDA                         16.373051
# evToOperatingCashFlow                             17.790674
# evToFreeCashFlow                                   26.06688
# earningsYield                                       0.02665
# freeCashFlowYield                                  0.037128
# debtToEquity                                       0.024732
# debtToAssets                                       0.197208
# netDebtToEBITDA                                   -0.544357
# currentRatio                                       3.326356
# interestCoverage                                       None
# incomeQuality                                      2.041305
# dividendYield                                      0.002476
# payoutRatio                                        0.092891
# salesGeneralAndAdministrativeToRevenue             0.141933
# researchAndDdevelopementToRevenue                  0.144653
# intangiblesToTotalAssets                           0.078591
# capexToOperatingCashFlow                          -0.317499
# capexToRevenue                                    -0.121297
# capexToDepreciation                               -0.721105
# stockBasedCompensationToRevenue                         0.0
# grahamNumber                                      10.618562
# roic                                                0.18709
# returnOnTangibleAssets                             0.129863
# grahamNetNet                                       1.585185
# workingCapital                                  16003000000
# tangibleAssetValue                              34141000000
# netCurrentAssetValue                            13585000000
# investedCapital                                    0.030651
# averageReceivables                               4871000000
# averagePayables                                  3620500000
# averageInventory                                 5473000000
# daysSalesOutstanding                              35.844862
# daysPayablesOutstanding                           46.439795
# daysOfInventoryOnHand                             70.470989
# receivablesTurnover                                10.18277
# payablesTurnover                                   7.859639
# inventoryTurnover                                  5.179436
# roe                                                0.149051
# capexPerShare                                     -0.560135
#
#                                                        2002  \
# period                                                   FY
# revenuePerShare                                    4.024057
# netIncomePerShare                                  0.468651
# operatingCashFlowPerShare                          1.372576
# freeCashFlowPerShare                               0.665464
# cashPerShare                                       1.892497
# bookValuePerShare                                  5.332732
# tangibleBookValuePerShare                          4.681702
# shareholdersEquityPerShare                         5.332732
# interestDebtPerShare                               0.205232
# marketCap                               105617880665.100006
# enterpriseValue                          99578880665.100006
# peRatio                                           33.884466
# priceToSalesRatio                                  3.946267
# pocfratio                                         11.569491
# pfcfRatio                                         23.863055
# pbRatio                                            2.977836
# ptbRatio                                           2.977836
# evToSales                                          3.720628
# enterpriseValueOverEBITDA                         10.429292
# evToOperatingCashFlow                             10.907972
# evToFreeCashFlow                                  22.498617
# earningsYield                                      0.029512
# freeCashFlowYield                                  0.041906
# debtToEquity                                       0.026193
# debtToAssets                                       0.197992
# netDebtToEBITDA                                   -0.632488
# currentRatio                                       2.869598
# interestCoverage                                       None
# incomeQuality                                      2.928778
# dividendYield                                      0.005046
# payoutRatio                                        0.170998
# salesGeneralAndAdministrativeToRevenue             0.161934
# researchAndDdevelopementToRevenue                  0.150725
# intangiblesToTotalAssets                           0.097911
# capexToOperatingCashFlow                          -0.515171
# capexToRevenue                                    -0.175721
# capexToDepreciation                               -0.880052
# stockBasedCompensationToRevenue                         0.0
# grahamNumber                                       7.498788
# roic                                               0.116453
# returnOnTangibleAssets                             0.078132
# grahamNetNet                                       1.037363
# workingCapital                                  12330000000
# tangibleAssetValue                              31138000000
# netCurrentAssetValue                            10169000000
# investedCapital                                    0.038485
# averageReceivables                               4678000000
# averagePayables                                  3562000000
# averageInventory                                 5351500000
# daysSalesOutstanding                              35.103497
# daysPayablesOutstanding                           41.885691
# daysOfInventoryOnHand                              61.78343
# receivablesTurnover                               10.397824
# payablesTurnover                                   8.714193
# inventoryTurnover                                  5.907733
# roe                                                0.087882
# capexPerShare                                     -0.707112
#
#                                                        2001          2000  \
# period                                                   FY            FY
# revenuePerShare                                    3.951608      5.026979
# netIncomePerShare                                  0.192228      1.570279
# operatingCashFlowPerShare                          1.288565      1.911909
# freeCashFlowPerShare                               0.200268      0.917126
# cashPerShare                                       1.719774      2.060367
# bookValuePerShare                                  5.335021      5.562975
# tangibleBookValuePerShare                           4.57162      4.677448
# shareholdersEquityPerShare                         5.335021      5.562975
# interestDebtPerShare                               0.217242      0.161723
# marketCap                               227806707911.200012  248652312500
# enterpriseValue                         221295707911.200012  246761312500
# peRatio                                          176.457558     23.602498
# priceToSalesRatio                                  8.583847      7.372719
# pocfratio                                         26.323863     19.385072
# pfcfRatio                                        169.373017     40.411557
# pbRatio                                            6.357988      6.662352
# ptbRatio                                           6.357988      6.662352
# evToSales                                           8.33851      7.316649
# enterpriseValueOverEBITDA                         25.577405     12.352889
# evToOperatingCashFlow                             25.571494     19.237648
# evToFreeCashFlow                                 164.532125     40.104228
# earningsYield                                      0.005667      0.042368
# freeCashFlowYield                                  0.005904      0.024745
# debtToEquity                                       0.029305      0.018943
# debtToAssets                                       0.192927      0.221566
# netDebtToEBITDA                                   -0.752543     -0.094664
# currentRatio                                       2.683866      2.445087
# interestCoverage                                       None          None
# incomeQuality                                      6.703331      1.217561
# dividendYield                                      0.002362       0.00189
# payoutRatio                                        0.416731      0.044613
# salesGeneralAndAdministrativeToRevenue             0.168205      0.150892
# researchAndDdevelopementToRevenue                  0.143035      0.115549
# intangiblesToTotalAssets                           0.115486      0.123913
# capexToOperatingCashFlow                          -0.844581     -0.520309
# capexToRevenue                                    -0.275406     -0.197889
# capexToDepreciation                                -1.12985     -1.380352
# stockBasedCompensationToRevenue                         0.0           0.0
# grahamNumber                                       4.803603     14.019522
# roic                                               0.059643      0.264537
# returnOnTangibleAssets                             0.032877      0.250809
# grahamNetNet                                       0.903328      1.105567
# workingCapital                                  11063000000   12500000000
# tangibleAssetValue                              30703000000   31381000000
# netCurrentAssetValue                             9068000000   10527000000
# investedCapital                                     0.04072      0.029071
# averageReceivables                               4694500000    5455500000
# averagePayables                                  3675000000    3984000000
# averageInventory                                 5340000000    5334000000
# daysSalesOutstanding                              35.854968     44.686147
# daysPayablesOutstanding                            47.87462     68.873913
# daysOfInventoryOnHand                             60.973159     64.661265
# receivablesTurnover                                 10.1799      8.168079
# payablesTurnover                                   7.624081      5.299539
# inventoryTurnover                                  5.986241      5.644801
# roe                                                0.036031      0.282273
# capexPerShare                                     -1.088297     -0.994783
#
#                                                 1999          1998  \
# period                                            FY            FY
# revenuePerShare                             4.420728        3.9378
# netIncomePerShare                           1.100181      0.909472
# operatingCashFlowPerShare                   1.705024      1.377548
# freeCashFlowPerShare                        1.193141      0.708633
# cashPerShare                                1.773165      1.142986
# bookValuePerShare                           4.893953      3.503747
# tangibleBookValuePerShare                   4.151775       3.48711
# shareholdersEquityPerShare                  4.893953      3.503747
# interestDebtPerShare                        0.143652      0.105216
# marketCap                               328452750000  217882500000
# enterpriseValue                         325712750000  216546500000
# peRatio                                    44.907404     35.906806
# priceToSalesRatio                          11.176044      8.293019
# pocfratio                                  28.976864     23.706071
# pfcfRatio                                  41.408567     46.083439
# pbRatio                                    10.095367      9.320379
# ptbRatio                                   10.095367      9.320379
# evToSales                                  11.082812      8.242169
# enterpriseValueOverEBITDA                  21.970506     18.130149
# evToOperatingCashFlow                      28.735135     23.560712
# evToFreeCashFlow                            41.06313     45.800867
# earningsYield                               0.022268       0.02785
# freeCashFlowYield                            0.02415        0.0217
# debtToEquity                                0.029353       0.03003
# debtToAssets                                0.258022      0.257189
# netDebtToEBITDA                            -0.184823     -0.111855
# currentRatio                                2.510072      2.321675
# interestCoverage                                None          None
# incomeQuality                               1.549768      1.514667
# dividendYield                               0.001114      0.000996
# payoutRatio                                 0.050041      0.035761
# salesGeneralAndAdministrativeToRevenue       0.13175      0.117078
# researchAndDdevelopementToRevenue           0.105856      0.095497
# intangiblesToTotalAssets                    0.112523      0.003527
# capexToOperatingCashFlow                   -0.300221     -0.485584
# capexToRevenue                             -0.115792      -0.16987
# capexToDepreciation                        -0.946066     -1.589954
# stockBasedCompensationToRevenue                  0.0           0.0
# grahamNumber                               11.006599      8.467445
# roic                                        0.265769       0.32645
# returnOnTangibleAssets                      0.187948      0.193495
# grahamNetNet                                 0.59988      0.444882
# workingCapital                           10720000000    7671000000
# tangibleAssetValue                       27601000000   23266000000
# netCurrentAssetValue                      6505000000    5381000000
# investedCapital                             0.029353       0.03003
# averageReceivables                        5241000000    5154500000
# averagePayables                           3475500000    3412500000
# averageInventory                          4952500000    5004500000
# daysSalesOutstanding                       45.952567     48.999163
# daysPayablesOutstanding                    42.248226     37.562872
# daysOfInventoryOnHand                      45.578743     47.768862
# receivablesTurnover                         7.942973      7.449107
# payablesTurnover                            8.639416      9.717042
# inventoryTurnover                           8.008119      7.640961
# roe                                         0.224804      0.259571
# capexPerShare                              -0.511883     -0.668915
#
#                                                 1997          1996  \
# period                                            FY            FY
# revenuePerShare                             3.833333      2.934544
# netIncomePerShare                           1.061927      0.725929
# operatingCashFlowPerShare                   1.530275      1.230715
# freeCashFlowPerShare                        0.842049      0.805039
# cashPerShare                                 1.51789      1.125282
# bookValuePerShare                           2.950306         2.375
# tangibleBookValuePerShare                   2.950306         2.375
# shareholdersEquityPerShare                  2.950306         2.375
# interestDebtPerShare                        0.068502      0.102477
# marketCap                               127019062500  133311000000
# enterpriseValue                         123365062500  129874000000
# peRatio                                    18.289282     25.850494
# priceToSalesRatio                           5.066576      6.394733
# pocfratio                                  12.691753     15.247741
# pfcfRatio                                   23.06502     23.310194
# pbRatio                                     6.583004      7.901316
# ptbRatio                                    6.583004      7.901316
# evToSales                                   4.920824      6.229865
# enterpriseValueOverEBITDA                   9.599647     13.222765
# evToOperatingCashFlow                      12.326645     14.854627
# evToFreeCashFlow                             22.4015     22.709215
# earningsYield                               0.054677      0.038684
# freeCashFlowYield                           0.043356        0.0429
# debtToEquity                                0.023218      0.043148
# debtToAssets                                0.331891      0.289151
# netDebtToEBITDA                            -0.284336     -0.349929
# currentRatio                                2.635714      2.813901
# interestCoverage                                None          None
# incomeQuality                               1.441037      1.695366
# dividendYield                               0.001417       0.00111
# payoutRatio                                 0.025918      0.028699
# salesGeneralAndAdministrativeToRevenue      0.115317      0.111383
# researchAndDdevelopementToRevenue           0.093618      0.086727
# intangiblesToTotalAssets                         0.0           0.0
# capexToOperatingCashFlow                    -0.44974     -0.345877
# capexToRevenue                             -0.179537     -0.145057
# capexToDepreciation                        -2.053376     -1.601695
# stockBasedCompensationToRevenue                  0.0           0.0
# grahamNumber                                8.395992      6.228309
# roic                                        0.432502      0.400223
# returnOnTangibleAssets                      0.240478      0.217274
# grahamNetNet                                  0.5763      0.643264
# workingCapital                            9847000000    8821000000
# tangibleAssetValue                              None          None
# netCurrentAssetValue                      6282000000    6821000000
# investedCapital                             0.023218      0.043148
# averageReceivables                        5110000000    5252500000
# averagePayables                           3494000000    3275000000
# averageInventory                          5062000000    4860000000
# daysSalesOutstanding                       50.054647     65.184199
# daysPayablesOutstanding                    51.639517     38.595046
# daysOfInventoryOnHand                      62.283057     51.499891
# receivablesTurnover                          7.29203      5.599517
# payablesTurnover                             7.06823      9.457172
# inventoryTurnover                           5.860342      7.087394
# roe                                         0.359938      0.305654
# capexPerShare                              -0.688226     -0.425676
#
#                                                1995            1994
# period                                           FY              FY
# revenuePerShare                            2.291007        1.649094
# netIncomePerShare                          0.504242          0.3275
# operatingCashFlowPerShare                  0.569287        0.426695
# freeCashFlowPerShare                       0.067308        0.077295
# cashPerShare                               0.347568        0.344963
# bookValuePerShare                          1.716629        1.326461
# tangibleBookValuePerShare                  1.716629        1.326461
# shareholdersEquityPerShare                 1.716629        1.326461
# interestDebtPerShare                       0.056561        0.130113
# marketCap                               48122753536  30564885496.25
# enterpriseValue                         47059753536  30293885496.25
# peRatio                                   13.494883       13.358779
# priceToSalesRatio                          2.970174        2.652972
# pocfratio                                 11.952994       10.253232
# pfcfRatio                                101.098222        56.60164
# pbRatio                                    3.963983         3.29825
# ptbRatio                                   3.963983         3.29825
# evToSales                                  2.904564        2.629449
# enterpriseValueOverEBITDA                  6.706535        6.514814
# evToOperatingCashFlow                      11.68896       10.162323
# evToFreeCashFlow                          98.865028       56.099788
# earningsYield                              0.074102        0.074857
# freeCashFlowYield                          0.009891        0.017667
# debtToEquity                               0.032949        0.042301
# debtToAssets                               0.306444        0.329256
# netDebtToEBITDA                           -0.151489        -0.05828
# currentRatio                               2.237358        2.039352
# interestCoverage                               None            None
# incomeQuality                              1.128996        1.302885
# dividendYield                              0.002411         0.00301
# payoutRatio                                0.032529         0.04021
# salesGeneralAndAdministrativeToRevenue     0.113751        0.125597
# researchAndDdevelopementToRevenue           0.07999        0.096433
# intangiblesToTotalAssets                        0.0             0.0
# capexToOperatingCashFlow                  -0.881769       -0.818853
# capexToRevenue                            -0.219109       -0.211874
# capexToDepreciation                       -2.574329       -2.331423
# stockBasedCompensationToRevenue                 0.0             0.0
# grahamNumber                               4.413153        3.126397
# roic                                        0.37825        0.313844
# returnOnTangibleAssets                     0.203725        0.165605
# grahamNetNet                               0.061227       -0.010163
# workingCapital                           4478000000      3143000000
# tangibleAssetValue                             None            None
# netCurrentAssetValue                     2733000000      1618000000
# investedCapital                            0.032949         0.09809
# averageReceivables                       4949000000      4380000000
# averagePayables                          3222500000      3078000000
# averageInventory                         5215500000      4798000000
# daysSalesOutstanding                      70.197506       62.665567
# daysPayablesOutstanding                   40.373832       37.638989
# daysOfInventoryOnHand                      93.64486         76.5217
# receivablesTurnover                        5.199615         5.82457
# payablesTurnover                           9.040509        9.697391
# inventoryTurnover                          3.897705        4.769889
# roe                                         0.29374        0.246898
# capexPerShare                              -0.50198         -0.3494
#
# [58 rows x 28 columns]

# %%
# Getting prices
curVal = fa.stock_data('INTC', start='1999-9-01', end='2022-08-01', interval='1mo')
print(curVal['close'])
# Out:
# 1999-09-01    37.156250
# 1999-10-01    38.718750
# 1999-11-01    38.343750
# 1999-12-01    41.156250
# 2000-01-01    49.468750
#                 ...
# 2022-04-01    43.590000
# 2022-05-01    44.419998
# 2022-06-01    37.410000
# 2022-07-01    36.310001
# 2022-08-01    31.920000
# Name: close, Length: 276, dtype: float64

# %%
# Getting key ratios
keyRat = fa.key_metrics('INTC', key, period='quarter', limit=(23 * 4))
keyRat.transpose()
# Out:
#         period revenuePerShare netIncomePerShare operatingCashFlowPerShare  \
# 2022-07     Q2        3.736829         -0.110732                  0.197317
# 2022-04     Q1        4.510445          1.993856                  1.447776
# 2021-12     Q4        5.044974          1.136151                  1.424674
# 2021-09     Q3         4.72593          1.680128                  2.437823
# 2021-06     Q2        4.848358          1.249938                   2.16004
# ...        ...             ...               ...                       ...
# 2000-09     Q3        1.299449          0.373419                  0.448281
# 2000-07     Q2         1.23696          0.467511                  0.470343
# 2000-04     Q1        1.196199          0.403472                  0.491021
# 1999-12     Q4         1.17853          0.302526                  0.491533
# 1999-09     Q3        1.101955          0.219248                  0.561654
#
#         freeCashFlowPerShare cashPerShare bookValuePerShare  \
# 2022-07            -1.572195     6.596098         24.687317
# 2022-04             0.268862     9.509953         25.346768
# 2021-12            -0.450971     6.982797         23.443352
# 2021-09              1.34425     8.528688         22.183452
# 2021-06             1.204742     6.139047         21.043961
# ...                      ...          ...               ...
# 2000-09              0.16178     2.084685          5.611698
# 2000-07             0.283756     2.033383          5.457526
# 2000-04              0.33029     1.678539          5.403023
# 1999-12                  0.5     1.691734          4.669202
# 1999-09             0.277594      1.78812          4.388271
#
#         tangibleBookValuePerShare shareholdersEquityPerShare  \
# 2022-07                  16.39122                  24.687317
# 2022-04                 17.034161                  25.346768
# 2021-12                 15.030229                  23.443352
# 2021-09                 13.695395                  22.183452
# 2021-06                 12.452704                  21.043961
# ...                           ...                        ...
# 2000-09                  4.694449                   5.611698
# 2000-07                  4.527571                   5.457526
# 2000-04                  4.508381                   5.403023
# 1999-12                  3.961108                   4.669202
# 1999-09                      3.92                   4.388271
#
#         interestDebtPerShare  ... averagePayables averageInventory  \
# 2022-07             8.668049  ...      7577500000      12054500000
# 2022-04              9.39887  ...      7210000000      11935000000
# 2021-12             9.396658  ...      6478500000      11355500000
# 2021-09             9.960108  ...      7001000000      10866500000
# 2021-06             8.776982  ...      6563500000      10376000000
# ...                      ...  ...             ...              ...
# 2000-09             0.140795  ...      4785000000       6935500000
# 2000-07             0.129657  ...      4589000000       6771000000
# 2000-04             0.129901  ...      4485000000       6736000000
# 1999-12             0.137055  ...      4290000000       6706500000
# 1999-09             0.132932  ...      4388000000       6780500000
#
#         daysSalesOutstanding daysPayablesOutstanding daysOfInventoryOnHand  \
# 2022-07            35.615821                73.45901            112.560099
# 2022-04            34.689697               71.237238            117.921836
# 2021-12            41.461906                54.33659            101.884652
# 2021-09            39.391413               72.375089             104.40682
# 2021-06            34.201009               63.208309             94.187537
# ...                      ...                     ...                   ...
# 2000-09            47.149238                67.47141             55.349428
# 2000-07            46.984337               53.950655             44.054219
# 2000-04            41.413737               52.994312             46.279692
# 1999-12            40.550414               38.822418             41.882872
# 1999-09            42.912118               46.576338             48.360872
#
#         receivablesTurnover payablesTurnover inventoryTurnover       roe  \
# 2022-07            2.526967         1.225173          0.799573 -0.004485
# 2022-04             2.59443         1.263384          0.763217  0.078663
# 2021-12            2.170667         1.656342          0.883352  0.048464
# 2021-09            2.284762         1.243522          0.862013  0.075738
# 2021-06            2.631501         1.423863           0.95554  0.059397
# ...                     ...              ...               ...       ...
# 2000-09            1.908833         1.333898          1.626033  0.066543
# 2000-07            1.915532         1.668191          2.042937  0.085664
# 2000-04            2.173192         1.698295          1.944697  0.074675
# 1999-12            2.219459         2.318248           2.14885  0.064792
# 1999-09             2.09731         1.932312          1.861009  0.049962
#
#         capexPerShare
# 2022-07     -1.769512
# 2022-04     -1.178914
# 2021-12     -1.875645
# 2021-09     -1.093573
# 2021-06     -0.955298
# ...               ...
# 2000-09     -0.286501
# 2000-07     -0.186587
# 2000-04      -0.16073
# 1999-12             0
# 1999-09      -0.28406
#
# [92 rows x 58 columns]

# %%
import fundamentalanalysis as fa
from datetime import date
import numpy as np
import pandas as pd

keyfile = open('apikey.txt', 'r')
key = keyfile.readline()
keyfile.close()

data = fa.stock_data('SPY',  start='1999-01-01', end='2022-01-01', interval='1mo')
data.index.array


data['dates'] = pd.to_datetime(data.index)
data['months'] = data['dates'].dt.month
data = data[data.months.isin([1, 4, 7, 10])]
data[['close', 'months']]

def calc_quarter(date):
    return '{:d}Q{:d}'.format(date.year, date.month // 3 + 1)


def get_quarter_closes(ticker, start, end):
    allData = fa.stock_data(ticker, start=start, end=end, interval='1mo')
    allData['dates'] = pd.to_datetime(allData.index)
    allData['months'] = allData['dates'].dt.month
    allData['ticker'] = ticker
    allData['quarter']  = allData['dates'].map(calc_quarter)
    allData = allData[allData.months.isin([1, 4, 7, 10])]
    allData['price'] = (allData['high'] + allData['low'] + allData['open'] + allData['close']) / 4
    allData.drop(['high', 'volume', 'low', 'open', 'close', 'adjclose', 'dates', 'months'], axis=1, inplace=True)
    allData.set_index(['quarter'])
    allData.sort_values(['quarter'])
    return allData

spy_closes = get_quarter_closes('SPY', '1999-01-01', '2022-01-01')
closes = get_quarter_closes('INTC', '1999-01-01', '2022-01-01')
closes
# Out:
#            ticker quarter      price
# 1999-01-01   INTC  1999Q1  32.765625
# 1999-04-01   INTC  1999Q2  30.363281
# 1999-07-01   INTC  1999Q3  32.468750
# 1999-10-01   INTC  1999Q4  37.062500
# 2000-01-01   INTC  2000Q1  45.775391
# ...           ...     ...        ...
# 2021-01-01   INTC  2021Q1  54.670000
# 2021-04-01   INTC  2021Q2  61.952499
# 2021-07-01   INTC  2021Q3  54.905001
# 2021-10-01   INTC  2021Q4  51.647500
# 2022-01-01   INTC  2022Q1  50.762500
#
# [93 rows x 3 columns]

# %%
fa.stock_data('INTC', start='1999-01-01', end='2022-01-01', interval='1mo')[-20:]
# Out:
#                volume       high        low       open      close   adjclose
# 2020-06-01  570572500  65.110001  56.759998  62.490002  59.830002  56.057896
# 2020-07-01  808654500  61.930000  46.970001  59.910000  47.730000  44.720764
# 2020-08-01  667321500  51.500000  47.700001  48.270000  50.950001  47.737762
# 2020-09-01  680429800  52.680000  48.419998  50.910000  51.779999  48.844917
# 2020-10-01  738437500  56.230000  43.610001  52.400002  44.279999  41.770050
# 2020-11-01  676942800  48.500000  44.240002  44.959999  48.349998  45.609344
# 2020-12-01  883810300  52.650002  45.240002  48.750000  49.820000  47.337845
# 2021-01-01  962555600  63.950001  49.330002  49.889999  55.509998  52.744358
# 2021-02-01  511339300  63.540001  55.709999  55.950001  60.779999  57.751789
# 2021-03-01  770803800  67.440002  57.910000  61.720001  64.000000  61.180485
# 2021-04-01  654934800  68.489998  57.070000  64.720001  57.529999  54.995518
# 2021-05-01  495384200  58.009998  53.419998  57.860001  57.119999  54.603580
# 2021-06-01  511873100  58.419998  55.099998  57.610001  56.139999  53.997292
# 2021-07-01  516953700  57.459999  52.310001  56.130001  53.720001  51.669659
# 2021-08-01  402375000  54.869999  51.419998  53.990002  54.060001  51.996681
# 2021-09-01  413346700  55.490002  52.320000  54.110001  53.279999  51.579468
# 2021-10-01  672042200  56.070000  47.869999  53.650002  49.000000  47.436069
# 2021-11-01  617076700  51.990002  48.119999  49.400002  49.200001  47.629688
# 2021-12-01  714651800  55.000000  48.330002  49.840000  51.500000  50.202991
# 2022-01-01  890542800  56.279999  46.299999  51.650002  48.820000  47.590485

# %% [markdown]
# Excellent, the dates in these values come as datetime objects. This works well!

# %%
# now I need to turn these quarterly closes into quarterly increases and decreases
def proc_losses_and_gains(quarter_closes):
    closes = np.array(quarter_closes['price'])
    offset = np.roll(closes, -1)
    
    close_vals = ((offset - closes) / closes)[:-1]
    quarter_closes.drop(quarter_closes.tail(1).index, inplace=True)

    quarter_closes['change'] = close_vals

    return close_vals

print(proc_losses_and_gains(spy_closes))
spy_closes
# Out:
# [ 0.05732325  0.03027078 -0.03397223  0.08554117  0.01885192  0.00018799
#  -0.0323005  -0.04946921 -0.10415527  0.01186577 -0.12551007  0.07154976
#  -0.02388493 -0.17124058 -0.07751076  0.04011082  0.00552537  0.1129991
#   0.04238296  0.09895316 -0.0046635  -0.00586225  0.00399822  0.06309375
#  -0.02230826  0.04045462 -0.00571912  0.04802304  0.02941643 -0.02993751
#   0.07348606  0.05046231  0.019899    0.02652432  0.02724566 -0.09217027
#  -0.02172782 -0.07757117 -0.17941217 -0.15665543 -0.04160798  0.13405341
#   0.10815386  0.05553171  0.07624627 -0.10295695  0.09272796  0.09652244
#   0.04786486 -0.02020824 -0.09569788  0.09281023  0.07625598 -0.02211358
#   0.0499698   0.02975129  0.06614957  0.04846397  0.03926973  0.0554106
#   0.03171357  0.0460278   0.00099833  0.03728424  0.02536793  0.00442392
#  -0.04422395 -0.02684797  0.06119954  0.03214539  0.00596808  0.05825196
#   0.04387745  0.03390351  0.04072639  0.08444517 -0.04596973  0.04883052
#   0.01027661 -0.07685069  0.12379984  0.02859436 -0.00019318  0.0908404
#  -0.17044773  0.18115741  0.05380425  0.11574748  0.09261051  0.05906645
#   0.02599428  0.0286012 ]
#            ticker quarter       price    change
# 1999-01-01    SPY  1999Q1  124.976562  0.057323
# 1999-04-01    SPY  1999Q2  132.140625  0.030271
# 1999-07-01    SPY  1999Q3  136.140625 -0.033972
# 1999-10-01    SPY  1999Q4  131.515625  0.085541
# 2000-01-01    SPY  2000Q1  142.765625  0.018852
# ...           ...     ...         ...       ...
# 2020-10-01    SPY  2020Q4  335.212502  0.115747
# 2021-01-01    SPY  2021Q1  374.012505  0.092611
# 2021-04-01    SPY  2021Q2  408.649994  0.059066
# 2021-07-01    SPY  2021Q3  432.787498  0.025994
# 2021-10-01    SPY  2021Q4  444.037498  0.028601
#
# [92 rows x 4 columns]

# %%
# we need to be able to figure out where our range starts for our labels of interest
def find_offset(myQuar, start='1998Q4'):
    sYear = int(start[:4])
    sQ = int(start[-1])
    
    year = int(myQuar[:4])
    q = int(myQuar[-1])

    dQ = q - sQ # this is the difference in quarters
    dYear = year - sYear

    return dYear * 4 + dQ

find_offset('2021Q3')
# Out:
# 91

# %%
# Now I am able to get information that I can use to make labels for these stocks. 
# I have to make the labels by creating this indicator function

def indicator(diff):
    if diff > 0: #S&P better
        return 0
    else: # this better
        return 1

# I want this to return a dataframe shaped like |ticker|quarter|indicator|
spy_closes = get_quarter_closes('SPY', '1999-01-01', '2022-01-01')
spy_changes = proc_losses_and_gains(spy_closes)
def create_label(ticker, start='1999-01-01', end='2022-01-01', spy=spy_changes):
    # first we need to get the closes
    tick_closes = get_quarter_closes(ticker, start, end)
    tick_changes = proc_losses_and_gains(tick_closes)

    # then we need to find where our closes start
    start_q = tick_closes['quarter'][0]

    # we need the differences in the changes from
    tick_closes['diff'] = spy_changes[find_offset(start_q)] - tick_changes
    tick_closes['label'] = tick_closes['diff'].map(indicator)

    return tick_closes

create_label('AAPL')
# Out:
#            ticker quarter       price    change      diff  label
# 1999-01-01   AAPL  1999Q1    0.374302 -0.029817  0.060088      0
# 1999-04-01   AAPL  1999Q2    0.363142  0.252785 -0.222514      1
# 1999-07-01   AAPL  1999Q3    0.454939  0.387612 -0.357341      1
# 1999-10-01   AAPL  1999Q4    0.631278  0.473149 -0.442878      1
# 2000-01-01   AAPL  2000Q1    0.929966  0.209571 -0.179301      1
# ...           ...     ...         ...       ...       ...    ...
# 2020-10-01   AAPL  2020Q4  114.902500  0.168273 -0.138002      1
# 2021-01-01   AAPL  2021Q1  134.237501 -0.041475  0.071746      0
# 2021-04-01   AAPL  2021Q2  128.670004  0.104026 -0.073755      1
# 2021-07-01   AAPL  2021Q3  142.055000  0.026257  0.004013      0
# 2021-10-01   AAPL  2021Q4  145.785000  0.183678 -0.153407      1
#
# [92 rows x 6 columns]

# %% [markdown]
# # Creating actual data points
#
# We have been able thus far to create labels, now we need a way to create data points for specific tickers. A large portion of the difficult part should theoretically be handled. We need to get the information about the stock that is going in to our feature list and add that to the information we need for our feature set.

# %%
features = ['peRatio', 'netIncomePerShare', 'freeCashFlowPerShare', 'pbRatio', 'roe', 'payoutRatio', 'dividendYield', 'debtToEquity', 'priceToSalesRatio', 'quarter', 'period']

# this is the quarter for which the stats were collected
# meaning it should be associated with the labels from the
# next quarter
def calc_metrics_quarter(date):
    quarter = ((date.month % 12) // 3 - 1) % 4 + 1
    yearMod = 0
    if quarter == 4 and date.month < 6:
        yearMod == -1
    return str(date.year + yearMod) + 'Q' + str(quarter)


# this will get our metrics which will be used as part of our
# feature set for our stocks
def get_metrics(ticker, limit=95, feature_set_values=features):
    metrics = fa.key_metrics(ticker, key, 'quarter', limit=95).transpose()
    metrics['date'] = pd.to_datetime(metrics.index)
    metrics['quarter'] = metrics['date'].map(calc_metrics_quarter)
    metrics.drop(metrics.columns.difference(feature_set_values), axis=1, inplace=True)

    return metrics[::-1]


metrics = get_metrics('AAPL')

metrics
# Out:
#         period netIncomePerShare freeCashFlowPerShare    peRatio  \
# 1998-12     Q1          0.010033             0.014389   9.094006
# 1999-03     Q2          0.008839             0.016368   8.396918
# 1999-06     Q3          0.012582              0.00502   7.484331
# 1999-09     Q4          0.006154               0.0112  23.552856
# 2000-01     Q1          0.010146             0.018574  22.618616
# ...        ...               ...                  ...        ...
# 2021-06     Q3          1.307566             1.142617  25.449958
# 2021-09     Q4          1.246488             1.029713  29.466787
# 2021-12     Q1          2.112651             2.694225  21.339298
# 2022-03     Q2           1.52577             1.564936  28.628169
# 2022-06     Q3          1.202875             1.286275  29.441966
#
#         priceToSalesRatio    pbRatio debtToEquity dividendYield payoutRatio  \
# 1998-12          3.233424   2.875276       0.4961          None         0.0
# 1999-03          2.963618   2.084752      0.43908          None         0.0
# 1999-06          3.900691   2.046221      0.10101          None         0.0
# 1999-09          7.827446    3.36903     0.096649          None         0.0
# 2000-01          7.066507    3.75098     0.067966          None         0.0
# ...                   ...        ...          ...           ...         ...
# 2021-06         27.181958  34.435837     1.645177      0.001702    0.173243
# 2021-09         29.058155  38.394164     1.729371      0.001503     0.17712
# 2021-12         23.848639  41.093249     1.482358      0.001263    0.107768
# 2022-03         29.441005  42.492649     1.533005      0.001255    0.143743
# 2022-06         27.599692  39.403907     1.629752      0.001664    0.196019
#
#               roe quarter
# 1998-12  0.079043  1998Q4
# 1999-03  0.062069  1999Q1
# 1999-06   0.06835  1999Q2
# 1999-09   0.03576  1999Q3
# 2000-01  0.041459  2000Q4
# ...           ...     ...
# 2021-06   0.33827  2021Q2
# 2021-09  0.325741  2021Q3
# 2021-12  0.481427  2021Q4
# 2022-03  0.371074  2022Q1
# 2022-06   0.33459  2022Q2
#
# [95 rows x 11 columns]

# %%
labels = create_label('AAPL')
labels
# Out:
#            ticker quarter       price    change      diff  label
# 1999-01-01   AAPL  1999Q1    0.374302 -0.029817  0.060088      0
# 1999-04-01   AAPL  1999Q2    0.363142  0.252785 -0.222514      1
# 1999-07-01   AAPL  1999Q3    0.454939  0.387612 -0.357341      1
# 1999-10-01   AAPL  1999Q4    0.631278  0.473149 -0.442878      1
# 2000-01-01   AAPL  2000Q1    0.929966  0.209571 -0.179301      1
# ...           ...     ...         ...       ...       ...    ...
# 2020-10-01   AAPL  2020Q4  114.902500  0.168273 -0.138002      1
# 2021-01-01   AAPL  2021Q1  134.237501 -0.041475  0.071746      0
# 2021-04-01   AAPL  2021Q2  128.670004  0.104026 -0.073755      1
# 2021-07-01   AAPL  2021Q3  142.055000  0.026257  0.004013      0
# 2021-10-01   AAPL  2021Q4  145.785000  0.183678 -0.153407      1
#
# [92 rows x 6 columns]

# %%
metrics = get_metrics('')
metrics
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# File c:\Python38\lib\site-packages\fundamentalanalysis\ratios.py:38, in key_metrics(ticker, api_key, period, TTM, limit)
#      37 try:
# ---> 38     response = urlopen(URL)
#      39     data = json.loads(response.read().decode("utf-8"))
#
# File c:\Python38\lib\urllib\request.py:222, in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     opener = _opener
# --> 222 return opener.open(url, data, timeout)
#
# File c:\Python38\lib\urllib\request.py:531, in OpenerDirector.open(self, fullurl, data, timeout)
#     530     meth = getattr(processor, meth_name)
# --> 531     response = meth(req, response)
#     533 return response
#
# File c:\Python38\lib\urllib\request.py:640, in HTTPErrorProcessor.http_response(self, request, response)
#     639 if not (200 <= code < 300):
# --> 640     response = self.parent.error(
#     641         'http', request, response, code, msg, hdrs)
#     643 return response
#
# File c:\Python38\lib\urllib\request.py:569, in OpenerDirector.error(self, proto, *args)
#     568 args = (dict, 'default', 'http_error_default') + orig_args
# --> 569 return self._call_chain(*args)
#
# File c:\Python38\lib\urllib\request.py:502, in OpenerDirector._call_chain(self, chain, kind, meth_name, *args)
#     501 func = getattr(handler, meth_name)
# --> 502 result = func(*args)
#     503 if result is not None:
#
# File c:\Python38\lib\urllib\request.py:649, in HTTPDefaultErrorHandler.http_error_default(self, req, fp, code, msg, hdrs)
#     648 def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#
# HTTPError: HTTP Error 404:
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# c:\Users\dwarf\Documents\School\2022\Fall\CS4824\fundamental-analysis\data-preparation.ipynb Cell 31 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/dwarf/Documents/School/2022/Fall/CS4824/fundamental-analysis/data-preparation.ipynb#X56sZmlsZQ%3D%3D?line=0'>1</a> metrics = get_metrics('')
#       <a href='vscode-notebook-cell:/c%3A/Users/dwarf/Documents/School/2022/Fall/CS4824/fundamental-analysis/data-preparation.ipynb#X56sZmlsZQ%3D%3D?line=1'>2</a> metrics
#
# c:\Users\dwarf\Documents\School\2022\Fall\CS4824\fundamental-analysis\data-preparation.ipynb Cell 31 in get_metrics(ticker, limit, feature_set_values)
#      <a href='vscode-notebook-cell:/c%3A/Users/dwarf/Documents/School/2022/Fall/CS4824/fundamental-analysis/data-preparation.ipynb#X56sZmlsZQ%3D%3D?line=15'>16</a> def get_metrics(ticker, limit=95, feature_set_values=features):
# ---> <a href='vscode-notebook-cell:/c%3A/Users/dwarf/Documents/School/2022/Fall/CS4824/fundamental-analysis/data-preparation.ipynb#X56sZmlsZQ%3D%3D?line=16'>17</a>     metrics = fa.key_metrics(ticker, key, 'quarter', limit=95).transpose()
#      <a href='vscode-notebook-cell:/c%3A/Users/dwarf/Documents/School/2022/Fall/CS4824/fundamental-analysis/data-preparation.ipynb#X56sZmlsZQ%3D%3D?line=17'>18</a>     metrics['date'] = pd.to_datetime(metrics.index)
#      <a href='vscode-notebook-cell:/c%3A/Users/dwarf/Documents/School/2022/Fall/CS4824/fundamental-analysis/data-preparation.ipynb#X56sZmlsZQ%3D%3D?line=18'>19</a>     metrics['quarter'] = metrics['date'].map(calc_metrics_quarter)
#
# File c:\Python38\lib\site-packages\fundamentalanalysis\ratios.py:41, in key_metrics(ticker, api_key, period, TTM, limit)
#      39     data = json.loads(response.read().decode("utf-8"))
#      40 except HTTPError:
# ---> 41     raise ValueError("This endpoint is only for premium members. Please visit the subscription page to upgrade the "
#      42                      "plan (Starter or higher) at https://financialmodelingprep.com/developer/docs/pricing")
#      44 if 'Error Message' in data:
#      45     raise ValueError(data['Error Message'])
#
# ValueError: This endpoint is only for premium members. Please visit the subscription page to upgrade the plan (Starter or higher) at https://financialmodelingprep.com/developer/docs/pricing

# %%
# Now we need to come up with a clean way to combine our labels with our features
# It's important to properly pair quarterly values with labels from the following quarter
# that way we ensure we are using info to make a buy decision that we would have in real life
# (i.e., we have the fundamental stats before buying)

def build_data_points(labels, metrics):

    # we need to make sure we have the right number of metrics
    # hopefully we can assume the price data starts at the same time the metric data does
    num_labels = len(labels)
    num_metrics = len(metrics)

    if num_labels != num_metrics:
        metrics = metrics.drop(metrics.index[num_labels - num_metrics:])

    assert find_offset(labels['quarter'][0], metrics['quarter'][0]) == 1, 'Labels and features have incorrect start offset'
    assert find_offset(labels['quarter'][-1], metrics['quarter'][-1]) == 1, 'Labels and features have incorrect end offset'

    # now that we have proper offsets, we need to merge these into a table of data points

    points = pd.merge(metrics, labels, how='left', left_index=False, right_index=False, copy=True)
    points = points.drop(['diff', 'price', 'change', 'quarter', 'period'], axis=1)
    points = points.dropna()

    return points

labels = create_label('AAPL')
metrics = get_metrics('AAPL')
points = build_data_points(labels, metrics)
points
# Out:
#    netIncomePerShare freeCashFlowPerShare    peRatio priceToSalesRatio  \
# 56          0.497458              0.79769   9.146318           8.77719
# 57          0.362871             0.387881   10.55348          9.242857
# 58           0.26826             0.225961  13.197812          10.31225
# 59          0.296723             0.300278  14.526248         11.648289
# 60          0.521004              0.82208   9.598397          8.714119
# 61          0.417381             0.492055  11.484447          10.28835
# 62          0.322155             0.325315  17.844676         14.774583
# 63          0.356725             0.395949   17.65191           14.1926
# 64          0.771168             1.303122   9.238417          8.928443
# 65          0.585497             0.716499  13.156565         12.309701
# 66          0.465847             0.562795  17.005316         14.640924
# 67          0.492481             0.434618  14.557662         12.577576
# 68          0.825743             1.054924   8.085138          7.826404
# 69          0.476753             0.408115  13.789886         11.473342
# 70          0.358071             0.354993  16.302643         12.002021
# 71          0.419888              0.56308   16.77681         12.910967
# 72          0.844128             1.115187   8.575414          7.832586
# 73          0.527623             0.454859  17.017344         14.192702
# 74          0.419483             0.288879  21.457973         16.477198
# 75          0.520155             0.565888  18.518523         15.094046
# 76          0.981101             1.238491  10.780615          9.799782
# 77          0.687679             0.551705  15.148793         13.699502
# 78          0.589851             0.574591  19.614071         16.966825
# 79          0.735434             0.858153  19.184261         17.232285
# 80          1.053936             1.231835   9.264677          8.775675
# 81          0.618358             0.470254  19.199026         15.303624
# 82          0.549377              0.52706   22.51642          16.81168
# 83          0.761889             0.953781  17.950451         15.344777
# 84          1.259105             1.608649  14.385215         13.934791
# 85          0.644997              0.65698  24.005944         18.523682
# 86          0.652337             0.852507  33.881081         25.551733
# 87          0.742952             1.101678  37.781697         29.602612
# 88          1.697951             2.082241   20.12573         20.772454
# 89          1.410454              1.29597  21.484224         22.667985
# 90          1.307566             1.142617  25.449958         27.181958
# 91          1.246488             1.029713  29.466787         29.058155
#
#       pbRatio debtToEquity dividendYield payoutRatio       roe ticker  label
# 56   3.757183          0.0       0.00521    0.190625  0.102697   AAPL    0.0
# 57   2.974509          0.0      0.006181     0.26092  0.070463   AAPL    0.0
# 58   2.952961     0.137474      0.007717    0.407391  0.055937   AAPL    0.0
# 59   3.532887     0.137273      0.006344     0.36861  0.060802   AAPL    1.0
# 60    3.87003     0.130787      0.005517    0.211827  0.100799   AAPL    1.0
# 61   3.907688     0.141139      0.005666    0.260295  0.085065   AAPL    1.0
# 62   4.572864     0.240036      0.005184    0.370031  0.064065   AAPL    1.0
# 63   5.359489     0.259864      0.004732    0.334121  0.075905   AAPL    1.0
# 64   5.400663     0.263557      0.004205    0.155404  0.146147   AAPL    1.0
# 65   5.535291     0.310621      0.003841    0.202152  0.105181   AAPL    1.0
# 66   5.778806     0.377308      0.004204    0.285942  0.084956   AAPL    0.0
# 67   5.427152     0.447933      0.004576    0.266451  0.093201   AAPL    0.0
# 68   4.629444     0.414791         0.005    0.161701  0.143147   AAPL    0.0
# 69   4.446352     0.531777      0.005003     0.27596  0.080609   AAPL    0.0
# 70   4.017525     0.544796      0.006269    0.408799  0.061608   AAPL    0.0
# 71   4.716642     0.588129      0.005112    0.343022  0.070285   AAPL    1.0
# 72   4.635478     0.555608        0.0051    0.174948  0.135139   AAPL    1.0
# 73    5.59909     0.630443      0.004001    0.272373  0.082256   AAPL    1.0
# 74   5.649965     0.678603      0.004497    0.386027  0.065826   AAPL    0.0
# 75   5.920534     0.725171       0.00412    0.305208  0.079927   AAPL    1.0
# 76     6.1716     0.741246      0.003859    0.166409  0.143118   AAPL    1.0
# 77   6.601195     0.798893      0.003809    0.230791  0.108939   AAPL    0.0
# 78   7.862077     0.844966      0.004042    0.317128   0.10021   AAPL    1.0
# 79  10.116109     0.874826      0.003257    0.249912  0.131828   AAPL    1.0
# 80   6.275889     0.788764      0.004822    0.178713   0.16935   AAPL    0.0
# 81   8.386924     0.852078      0.003878    0.297812   0.10921   AAPL    1.0
# 82   9.378573     0.880567      0.004012     0.36131   0.10413   AAPL    1.0
# 83  10.859777     1.014577       0.00354    0.254201  0.151247   AAPL    1.0
# 84    14.2909     1.039618      0.002766    0.159156  0.248361   AAPL    1.0
# 85  13.773305     1.135939      0.003125    0.300027  0.143436   AAPL    0.0
# 86  21.098686     1.301126      0.002397    0.324891  0.155682   AAPL    1.0
# 87  29.312199     1.510078      0.001833    0.277046  0.193958   AAPL    1.0
# 88  34.955023     1.499169      0.001561    0.125648  0.434208   AAPL    1.0
# 89  29.354546      1.57047      0.001697    0.145874  0.341583   AAPL    0.0
# 90  34.435837     1.645177      0.001702    0.173243   0.33827   AAPL    1.0
# 91  38.394164     1.729371      0.001503     0.17712  0.325741   AAPL    0.0

# %%
# now we need to make a method to do all of this for a single stock

def generate_data(ticker):
    return build_data_points(create_label(ticker), get_metrics(ticker))

generate_data('CLB')
# Out:
#    netIncomePerShare freeCashFlowPerShare     peRatio priceToSalesRatio  \
# 40          0.756989             0.766108    9.884553          6.917222
# 41          0.635438             1.031062   14.391659          9.394694
# 42          0.649249             0.728142   16.779014         11.960447
# 43          0.674561             1.174039   19.103154          14.11112
# 44          0.514106             0.644673   28.719761         14.940051
# 45           0.68774             1.198783    23.77351         16.261434
# 46           0.76594             0.949475   24.089672         16.568462
# 47           0.86284             1.134791   25.508792         19.771875
# 48         -1.808943             0.584187  -12.306911         21.043517
# 49           1.02377             1.185473    24.94945         22.354321
# 50          0.871268             0.693249   32.005087          22.96202
# 51          0.963395             0.914281   23.310785         18.100376
# 52          1.113208             0.954507   25.590465         22.294565
# 53          1.126291             0.966628   29.204278         26.934774
# 54          1.106903             0.815446    26.17664         22.425008
# 55          1.144588             0.874937   26.347898         23.363091
# 56          1.182324             1.672146   23.113385         19.907481
# 57          1.227885             1.281521    27.30711           23.6543
# 58          1.306081             1.255085    28.96642         26.291072
# 59          1.364446             1.416026   31.003417         28.098266
# 60          1.434546             1.743051   33.277087         31.169418
# 61          1.361643             1.291577   36.433928          33.87011
# 62          1.432104             1.195728    29.16339          27.76843
# 63           1.51362             1.505426   24.172177         23.287936
# 64          1.517062             2.033298   19.831097         18.848796
# 65          0.730635              1.68751   35.753166         21.023397
# 66          0.811126             0.959919   35.148658         23.857647
# 67          0.787601              0.86122   31.678494          21.45082
# 68          0.363414             1.058408   74.804478         25.221433
# 69          0.356202             1.019138   78.894879         31.023768
# 70          0.376452             0.571709   82.274683         36.887501
# 71          0.378684             0.733014   74.158175         34.521018
# 72          0.351066             0.440395   85.482539         36.551155
# 73          0.400672             0.525402   72.078818         32.587358
# 74           0.51441             0.355804   49.216588         28.248206
# 75          0.477946             0.563976   51.627213         26.748538
# 76          0.491126             0.934904   57.006786         29.089883
# 77          0.531799             0.420416   50.009455         27.652287
# 78          0.561041             0.423315   56.239196         31.788765
# 79           0.50655             0.443299   57.773199         28.426571
# 80           0.19936             0.722141   74.814459         15.264643
# 81           0.91375             0.450514   18.859091         18.061675
# 82          0.618062             0.226199   21.389452          13.87547
# 83           0.53474             0.464047   21.795646         11.944316
# 84          0.232315             0.370624   40.537697         10.684009
# 85         -2.439487             0.418683   -1.059649          3.015438
# 86         -0.128515             0.533643  -39.528431          7.808962
# 87          0.066592             0.413892   57.288987          6.443122
# 88          0.303705            -0.342563   21.822135         10.388003
# 89          0.175279             0.111093   41.063032         12.282955
# 90          0.173986             0.141024   55.967104         15.195414
# 91          0.018893             0.188435  367.195303         10.880322
#
#         pbRatio debtToEquity dividendYield payoutRatio        roe ticker  \
# 40     8.799991     1.509032      0.001655    0.065426   0.222569    CLB
# 41     8.129047     0.958302       0.00137    0.078857   0.141211    CLB
# 42     8.519775     0.859031       0.00127    0.085248   0.126941    CLB
# 43     9.554969     0.828748      0.008244    0.629921   0.125044    CLB
# 44     9.711557     0.748518      0.000852    0.097896   0.084537    CLB
# 45    13.655016          0.0       0.00088    0.083727   0.143595    CLB
# 46    14.207233     0.094289      0.000868    0.083626   0.147441    CLB
# 47    16.063353      0.06566      0.008054    0.821762    0.15743    CLB
# 48    15.134357     0.030619      0.000615   -0.030292  -0.307436    CLB
# 49    16.486382     0.016138      0.002498     0.24933   0.165198    CLB
# 50     20.81732     0.008765      0.002153    0.275679   0.162609    CLB
# 51    31.154597     1.157908      0.002782    0.259399   0.334122    CLB
# 52    30.552688     1.253914      0.002147    0.219793   0.298477    CLB
# 53    29.962638     0.940784      0.002114    0.246926   0.256492    CLB
# 54    25.132957      0.93496      0.002399    0.251229   0.240032    CLB
# 55    24.609195     0.914454      0.002311    0.243603   0.233502    CLB
# 56    27.802524     1.284273      0.002581    0.238577   0.300719    CLB
# 57    33.907338     1.324238      0.002401    0.262301   0.310426    CLB
# 58    38.150497     1.378903      0.002123     0.24603   0.329265    CLB
# 59    43.073591      1.43649      0.001904    0.236139   0.347329    CLB
# 60    52.730541      1.63481      0.001686    0.224374   0.396148    CLB
# 61    55.383178     1.735301      0.002526    0.368101   0.380025    CLB
# 62    57.090858     2.558429      0.003021     0.35237   0.489405    CLB
# 63     67.32915     3.874427      0.003455    0.334075    0.69635    CLB
# 64    59.964538      4.06518      0.004177     0.33136   0.755941    CLB
# 65   169.571697    14.085039      0.005331     0.76242   1.185711    CLB
# 66  4339.495283   376.010705      0.004845    0.681156  30.865299    CLB
# 67  -345.658835   -34.955897      0.005535    0.701347  -2.727867    CLB
# 68  -158.545136   -14.828895      0.005057    1.513117  -0.529865    CLB
# 69  -142.749107   -12.195554      0.004891    1.543444   -0.45234    CLB
# 70    33.753507     1.286597      0.004269    1.404819   0.102563    CLB
# 71     31.43472     1.309501      0.004897    1.452515   0.105972    CLB
# 72    35.016699     1.430342      0.004578     1.56529   0.102409    CLB
# 73    34.156233     1.463205      0.004759    1.371977   0.118468    CLB
# 74    30.298836     1.584746      0.005439    1.070749   0.153906    CLB
# 75    29.171237     1.565659       0.00557    1.150284   0.141259    CLB
# 76    34.162195     1.567127      0.004907    1.118986   0.149816    CLB
# 77    31.840643     1.592503      0.005174    1.034979   0.159173    CLB
# 78    36.277926     1.571611      0.004358    0.980363   0.161266    CLB
# 79    32.879474     1.878485      0.004693    1.084554   0.142278    CLB
# 80    16.866291     1.848506      0.009199    2.752915    0.05636    CLB
# 81    16.684012     1.610002      0.007976    0.601679   0.221167    CLB
# 82     12.45867     1.540531      0.010401    0.889874   0.145617    CLB
# 83    10.874108     1.561915      0.011794    1.028235   0.124728    CLB
# 84     9.417354     1.716375      0.014571    2.362633   0.058078    CLB
# 85     6.993012     4.601923      0.024178    -0.10248  -1.649842    CLB
# 86    14.552889     5.540135      0.000492   -0.077852  -0.092041    CLB
# 87    10.039465      3.64051      0.000655    0.150186   0.043811    CLB
# 88    16.523219     4.412359      0.000377    0.032873   0.189294    CLB
# 89      9.38276     1.880416      0.000335    0.055028   0.057124    CLB
# 90    12.027192     1.755881      0.000257    0.057444   0.053724    CLB
# 91     8.199454     1.547601      0.000361    0.529748   0.005582    CLB
#
#     label
# 40    0.0
# 41    1.0
# 42    1.0
# 43    1.0
# 44    1.0
# 45    1.0
# 46    1.0
# 47    1.0
# 48    1.0
# 49    1.0
# 50    1.0
# 51    0.0
# 52    1.0
# 53    1.0
# 54    0.0
# 55    0.0
# 56    1.0
# 57    1.0
# 58    1.0
# 59    1.0
# 60    0.0
# 61    1.0
# 62    0.0
# 63    0.0
# 64    0.0
# 65    1.0
# 66    0.0
# 67    0.0
# 68    0.0
# 69    1.0
# 70    0.0
# 71    0.0
# 72    1.0
# 73    0.0
# 74    0.0
# 75    0.0
# 76    1.0
# 77    0.0
# 78    0.0
# 79    0.0
# 80    0.0
# 81    1.0
# 82    0.0
# 83    0.0
# 84    0.0
# 85    0.0
# 86    1.0
# 87    0.0
# 88    1.0
# 89    0.0
# 90    1.0
# 91    0.0

# %%
# Now for a cheap trick. We'll build sets and append them to a csv and ignore all ones that give us errors.
def build_dataset(filename, error_file, start_at=0):
    companies = fa.available_companies(key)[start_at + 1:]
    companies.reset_index(inplace=True)
    tickers = companies['symbol'].array
    counter = 0

    for ticker in tickers:
        data = None
        try:
            data = generate_data(ticker)
        except:
            errFile = open(error_file, 'a')
            errFile.write(ticker + '\n')
            errFile.close()

        if data is not None:
            data.to_csv(filename, mode='a', index=False, header=(counter == 0))
        
        counter += 1
        print('Latest Ticker: {:s}. {:4f}% completed'.format(ticker, 100 * counter / len(tickers)), end='\r')


build_dataset('dataset2.csv', 'error2.log')
# Out:
# Latest Ticker: PRME. 100.000000% completededededtedd
